# %% [markdown]
# ## Google Analytics - Customer Revenue Prediction

# %% [markdown]
# ## 1. Getting the data

# %%
#### Loading the Required Packages ############
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import gc
import sys

from pandas.io.json import json_normalize
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### Function to convert XML to dataframes

# %%
def load_df(csv_path, nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [str(column)+"."+str(subcolumn) for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print("Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %% [markdown]
# #### Calling the input train and test xml files to convert to dataframe

# %%
#train = load_df(os.getcwd()+'\\train.csv')
#test = load_df(os.getcwd()+'/test.csv')

# %% [markdown]
# #### Saving a CSV copy of generated dataframes

# %%
#train.to_csv('train_extracted.csv',encoding='utf8')
#test.to_csv('test_extracted.csv', encoding = 'utf8')

## Reading saved the data
train = pd.read_csv('train_extracted.csv',encoding='utf8',dtype={'fullVisitorId': 'str'})
test = pd.read_csv('test_extracted.csv', encoding = 'utf8',dtype={'fullVisitorId': 'str'})
# Out:
# C:\Users\arvra\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Combining train and test data
#
# For ease in computation of data transformation and other changes, we combine the train and test

# %%
train['data_source'] = 'train'
test['data_source'] = 'test'

all_data = pd.concat([train,test], axis = 0)

# %%
all_data.shape
# Out:
# (1708337, 56)

# %% [markdown]
# ## 2. Analyzing the Data

# %% [markdown]
# #### Emtpy values
#
# Checking the ratio of NULL/empty values

# %%
100 * float(train['totals_transactionRevenue'].isnull().sum())/len(train['totals_transactionRevenue'])
# Out:
# 98.72572768529513

# %% [markdown]
# #### Data Snapshot

# %%
#all_data.drop([u'Unnamed: 0'], axis = 1, inplace = True)
all_data.head()
# Out:
#   channelGrouping data_source      date device_browser  \
# 0  Organic Search       train  20160902         Chrome
# 1  Organic Search       train  20160902        Firefox
# 2  Organic Search       train  20160902         Chrome
# 3  Organic Search       train  20160902     UC Browser
# 4  Organic Search       train  20160902         Chrome
#
#               device_browserSize          device_browserVersion  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device_deviceCategory            device_flashVersion  device_isMobile  \
# 0               desktop  not available in demo dataset            False
# 1               desktop  not available in demo dataset            False
# 2               desktop  not available in demo dataset            False
# 3               desktop  not available in demo dataset            False
# 4                mobile  not available in demo dataset             True
#
#                  device_language      ...       trafficSource_campaign  \
# 0  not available in demo dataset      ...                    (not set)
# 1  not available in demo dataset      ...                    (not set)
# 2  not available in demo dataset      ...                    (not set)
# 3  not available in demo dataset      ...                    (not set)
# 4  not available in demo dataset      ...                    (not set)
#
#   trafficSource_campaignCode trafficSource_isTrueDirect trafficSource_keyword  \
# 0                        NaN                        NaN        (not provided)
# 1                        NaN                        NaN        (not provided)
# 2                        NaN                        NaN        (not provided)
# 3                        NaN                        NaN       google + online
# 4                        NaN                       True        (not provided)
#
#   trafficSource_medium trafficSource_referralPath trafficSource_source  \
# 0              organic                        NaN               google
# 1              organic                        NaN               google
# 2              organic                        NaN               google
# 3              organic                        NaN               google
# 4              organic                        NaN               google
#
#       visitId visitNumber visitStartTime
# 0  1472830385           1     1472830385
# 1  1472880147           1     1472880147
# 2  1472865386           1     1472865386
# 3  1472881213           1     1472881213
# 4  1472822600           2     1472822600
#
# [5 rows x 56 columns]

# %%
#### Distribution of the 'visitNumber' variable
all_data.visitNumber.describe()
# Out:
# count    1.708337e+06
# mean     2.335170e+00
# std      9.354034e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      4.570000e+02
# Name: visitNumber, dtype: float64

# %% [markdown]
# #### Response variable

# %%
all_data['totals_transactionRevenue'] = pd.to_numeric(all_data['totals_transactionRevenue'])
all_data['totals_transactionRevenue'].describe()
# Out:
# count    1.151500e+04
# mean     1.337448e+08
# std      4.482852e+08
# min      1.000000e+04
# 25%      2.493000e+07
# 50%      4.945000e+07
# 75%      1.076550e+08
# max      2.312950e+10
# Name: totals_transactionRevenue, dtype: float64

# %% [markdown]
# #### Distribution of other columns apart from Response variable

# %%
for each in all_data.columns:
    print(each)
    print(all_data[each].value_counts())
    print("\n")
# Out:
# channelGrouping
# Organic Search    738963
# Social            354971
# Direct            273134
# Referral          211307
# Display            51283
# Paid Search        45627
# Affiliates         32915
# (Other)              137
# Name: channelGrouping, dtype: int64
#
#
# data_source
# train    903653
# test     804684
# Name: data_source, dtype: int64
#
#
# date
# 20171212    9234
# 20171213    9131
# 20171004    5122
# 20170920    4880
# 20161128    4807
# 20170921    4715
# 20161115    4685
# 20171005    4679
# 20161114    4466
# 20161130    4435
# 20180321    4434
# 20161026    4375
# 20161129    4337
# 20161116    4334
# 20161004    4322
# 20161205    4265
# 20171017    4258
# 20180327    4227
# 20170426    4224
# 20161201    4200
# 20171127    4194
# 20161027    4162
# 20161121    4143
# 20171108    4136
# 20161117    4074
# 20161024    4063
# 20161110    4055
# 20171006    4033
# 20161103    4014
# 20180226    3989
#             ...
# 20170430    1594
# 20161001    1589
# 20161226    1586
# 20170115    1576
# 20170429    1566
# 20170611    1555
# 20170204    1549
# 20170423    1548
# 20170610    1545
# 20170604    1534
# 20170114    1526
# 20170205    1522
# 20170624    1510
# 20170416    1507
# 20170415    1506
# 20170527    1502
# 20171231    1495
# 20170528    1463
# 20170618    1432
# 20170507    1400
# 20170603    1399
# 20170617    1391
# 20161225    1386
# 20170506    1383
# 20170101    1364
# 20170514    1290
# 20170513    1251
# 20161230    1232
# 20161224    1231
# 20161231    1211
# Name: date, Length: 638, dtype: int64
#
#
# device_browser
# Chrome                                                  1173056
# Safari                                                   312165
# Firefox                                                   63845
# Internet Explorer                                         35474
# Android Webview                                           34266
# Edge                                                      20543
# Samsung Internet                                          15792
# Opera Mini                                                15018
# Safari (in-app)                                           14207
# Opera                                                      9585
# UC Browser                                                 5313
# YaBrowser                                                  3045
# Amazon Silk                                                1467
# Coc Coc                                                    1242
# Android Browser                                             941
# Mozilla Compatible Agent                                    663
# MRCHROME                                                    308
# Maxthon                                                     287
# Puffin                                                      251
# BlackBerry                                                  243
# Nintendo Browser                                            165
# Nokia Browser                                                96
# Iron                                                         40
# osee2unifiedRelease                                          27
# SeaMonkey                                                    26
# Mozilla                                                      22
# LYF_LS_4002_12                                               21
# Seznam                                                       18
# Apple-iPhone7C2                                              16
# Playstation Vita Browser                                     15
#                                                          ...
# ;__CT_JOB_ID__:58e2ecba-7666-4a10-b498-8216457ce472;          1
# wvsmagudcqeytijorlhxnfzkbp                                    1
# uybjlgntzwpacihremkqsxdovf                                    1
# hbijxvdyrgnatwzmlcpkfusqoe                                    1
# flobzsdixhuwqakptjmcrveygn                                    1
# efkaxnbyohqtspzlvcwrjmigdu                                    1
# ;__CT_JOB_ID__:6e9dcf2f-f58f-4938-91e3-77e00868177b;          1
# Changa 99695759                                               1
# cnwmpegudakrqzljtvfxohbysi                                    1
# fspmihbxzowgnuctrqykjlvade                                    1
# tfowdqmibyshaklxuregpcnzvj                                    1
# ;__CT_JOB_ID__:76fd1acb-e365-43c0-b967-908bcf5d5b59;          1
# Hisense M20-M_LTE                                             1
# ADM                                                           1
# Reddit                                                        1
# NokiaC7-00                                                    1
# mhwxofpevcagujznbsiqlrkytd                                    1
# afjurnqyolshpibxczdwktmvge                                    1
# User Agent                                                    1
# lhkbrtuwomdeafnqygvxcspizj                                    1
# zurcqesbhljxmpwdgnvkoyafit                                    1
# ;__CT_JOB_ID__:65da7e5f-0f05-4b5d-8d31-1f4d470a2b82;          1
# lpmqaxwbzyteokrfusnjhvdigc                                    1
# subjectAgent: NoticiasBoom                                    1
# Dillo                                                         1
# ;__CT_JOB_ID__:fe02e46f-b6ae-41f1-8563-3b40bbb623a9;          1
# ;__CT_JOB_ID__:97909e28-4228-4b55-8ad5-cc791f2b583c;          1
# epxmjusghnvircdfkwqlotzbay                                    1
# njroiedbwpmvykqlatxzuhcfgs                                    1
# wfpknuqxovyilmrdzbhgtecjas                                    1
# Name: device_browser, Length: 129, dtype: int64
#
#
# device_browserSize
# not available in demo dataset    1708337
# Name: device_browserSize, dtype: int64
#
#
# device_browserVersion
# not available in demo dataset    1708337
# Name: device_browserVersion, dtype: int64
#
#
# device_deviceCategory
# desktop    1171579
# mobile      471336
# tablet       65422
# Name: device_deviceCategory, dtype: int64
#
#
# device_flashVersion
# not available in demo dataset    1708337
# Name: device_flashVersion, dtype: int64
#
#
# device_isMobile
# False    1171670
# True      536667
# Name: device_isMobile, dtype: int64
#
#
# device_language
# not available in demo dataset    1708337
# Name: device_language, dtype: int64
#
#
# device_mobileDeviceBranding
# not available in demo dataset    1708337
# Name: device_mobileDeviceBranding, dtype: int64
#
#
# device_mobileDeviceInfo
# not available in demo dataset    1708337
# Name: device_mobileDeviceInfo, dtype: int64
#
#
# device_mobileDeviceMarketingName
# not available in demo dataset    1708337
# Name: device_mobileDeviceMarketingName, dtype: int64
#
#
# device_mobileDeviceModel
# not available in demo dataset    1708337
# Name: device_mobileDeviceModel, dtype: int64
#
#
# device_mobileInputSelector
# not available in demo dataset    1708337
# Name: device_mobileInputSelector, dtype: int64
#
#
# device_operatingSystem
# Windows             619720
# Macintosh           438514
# Android             299386
# iOS                 219334
# Linux                63971
# Chrome OS            51318
# (not set)            11815
# Windows Phone         1675
# Samsung                911
# Tizen                  709
# BlackBerry             350
# OS/2                   199
# Xbox                   133
# Nintendo Wii           100
# Firefox OS              97
# Nintendo WiiU           51
# FreeBSD                 18
# Playstation Vita        15
# Nintendo 3DS             9
# Nokia                    3
# SunOS                    3
# OpenBSD                  3
# SymbianOS                2
# NTT DoCoMo               1
# Name: device_operatingSystem, dtype: int64
#
#
# device_operatingSystemVersion
# not available in demo dataset    1708337
# Name: device_operatingSystemVersion, dtype: int64
#
#
# device_screenColors
# not available in demo dataset    1708337
# Name: device_screenColors, dtype: int64
#
#
# device_screenResolution
# not available in demo dataset    1708337
# Name: device_screenResolution, dtype: int64
#
#
# fullVisitorId
# 1957458976293878100    400
# 7282998257608986241    315
# 3884810646891698298    268
# 0824839726118485274    258
# 7477638593794484792    218
# 3608475193341679870    201
# 1856749147915772585    199
# 0720311197761340948    180
# 0348420048060754000    177
# 7498695963354635199    172
# 0232377434237234751    167
# 460252456180441002     162
# 3269834865385146569    157
# 7122741899604173060    154
# 1322101426801959631    153
# 8839221334461540297    152
# 0603203541488487946    148
# 7634897085866546110    148
# 3694234028523165868    139
# 4038076683036146727    138
# 7445235885559107095    138
# 185123961166899959     130
# 9801276214964695322    130
# 0949718915643445721    128
# 0827807801897731454    127
# 3525537916960843419    126
# 5211936831694160345    120
# 705991343467703841     119
# 6254908847172458133    117
# 9609104828919391966    114
#                       ...
# 4063356749353808393      1
# 4403519276901463170      1
# 0238325054198580055      1
# 8341040305951052916      1
# 0266034144531479687      1
# 1188330865541227613      1
# 9385991613302484598      1
# 7230538620290089418      1
# 1636478568060656421      1
# 7105260869793298901      1
# 4691368205145563499      1
# 499684111562719990       1
# 1414579312473085431      1
# 488742344184402776       1
# 7017107179547404222      1
# 5712371170986945650      1
# 2220773483478927824      1
# 4812504976979453219      1
# 0347497625680334790      1
# 3001311798309889209      1
# 6187511184116726753      1
# 6061435017199793071      1
# 2702256960049136260      1
# 2333830302150116237      1
# 6988666351745751672      1
# 7209089107207647584      1
# 9789365851951316617      1
# 157722538272537588       1
# 2029111578618128413      1
# 6658597533749748256      1
# Name: fullVisitorId, Length: 1323730, dtype: int64
#
#
# geoNetwork_city
# not available in demo dataset    932959
# Mountain View                     74110
# (not set)                         65867
# New York                          49460
# San Francisco                     36960
# Sunnyvale                         27923
# London                            23622
# San Jose                          20141
# Los Angeles                       17038
# Chicago                           15143
# Bangkok                           12468
# Bengaluru                         11428
# Ho Chi Minh City                  10393
# Toronto                           10196
# Istanbul                           9827
# Seattle                            9566
# Dublin                             9436
# Sydney                             8951
# Mumbai                             8563
# Hyderabad                          8353
# Paris                              8094
# Chennai                            8046
# Sao Paulo                          7828
# Austin                             7289
# Hanoi                              6966
# Singapore                          6475
# Santa Clara                        6475
# Jakarta                            6431
# Hong Kong                          6278
# New Delhi                          6177
#                                   ...
# Miami Shores                          6
# Pescara                               6
# Largo                                 6
# Augsburg                              6
# Kuwait City                           6
# Erzurum                               6
# Aneby                                 6
# Mueang Phitsanulok District           6
# Tallahassee                           6
# Miami Beach                           6
# Watford                               6
# Erfurt                                6
# Chisinau                              6
# Ulaanbaatar                           6
# Dar es Salaam                         6
# West Palm Beach                       6
# Amherst                               6
# North Attleborough                    6
# Seclin                                6
# Kumamoto                              5
# Croydon                               5
# Millbrae                              5
# Long Beach                            5
# Deep River                            5
# Getzville                             5
# North Creek                           4
# Morgan Hill                           4
# Daly City                             4
# Chandler                              3
# Boise                                 3
# Name: geoNetwork_city, Length: 956, dtype: int64
#
#
# geoNetwork_cityId
# not available in demo dataset    1708337
# Name: geoNetwork_cityId, dtype: int64
#
#
# geoNetwork_continent
# Americas     877403
# Asia         396719
# Europe       368037
# Africa        35481
# Oceania       28180
# (not set)      2517
# Name: geoNetwork_continent, dtype: int64
#
#
# geoNetwork_country
# United States               717217
# India                       105317
# United Kingdom               73341
# Canada                       51057
# Germany                      38516
# Japan                        36637
# Brazil                       35432
# Vietnam                      34869
# France                       32289
# Thailand                     29859
# Turkey                       29166
# Taiwan                       26560
# Mexico                       25270
# Australia                    23660
# Spain                        23431
# Netherlands                  22146
# Italy                        20694
# Russia                       19641
# Indonesia                    16675
# Poland                       15874
# Philippines                  14272
# Singapore                    13294
# Ireland                      12287
# South Korea                  11563
# Malaysia                     10820
# Argentina                    10128
# Sweden                        9895
# Ukraine                       9859
# Romania                       9589
# Israel                        9449
#                              ...
# Timor-Leste                     12
# San Marino                      12
# St. Kitts & Nevis               11
# Caribbean Netherlands           10
# Guinea-Bissau                    9
# British Virgin Islands           7
# Central African Republic         6
# Isle of Man                      6
# Equatorial Guinea                5
# St. Martin                       5
# Seychelles                       4
# Comoros                          4
# Vanuatu                          4
# Dominica                         4
# Cook Islands                     3
# American Samoa                   2
# St. Barthélemy                   2
# Marshall Islands                 2
# Montserrat                       1
# Tonga                            1
# St. Helena                       1
# Samoa                            1
# São Tomé & Príncipe              1
# St. Pierre & Miquelon            1
# Anguilla                         1
# Solomon Islands                  1
# Åland Islands                    1
# Micronesia                       1
# Eritrea                          1
# Norfolk Island                   1
# Name: geoNetwork_country, Length: 228, dtype: int64
#
#
# geoNetwork_latitude
# not available in demo dataset    1708337
# Name: geoNetwork_latitude, dtype: int64
#
#
# geoNetwork_longitude
# not available in demo dataset    1708337
# Name: geoNetwork_longitude, dtype: int64
#
#
# geoNetwork_metro
# not available in demo dataset         932959
# (not set)                             386896
# San Francisco-Oakland-San Jose CA     182745
# New York NY                            50419
# London                                 23643
# Los Angeles CA                         19953
# Chicago IL                             15300
# Seattle-Tacoma WA                      15251
# Austin TX                               7289
# Washington DC (Hagerstown MD)           7021
# Boston MA-Manchester NH                 5868
# Dallas-Ft. Worth TX                     5787
# Houston TX                              5704
# Atlanta GA                              5464
# Detroit MI                              4517
# JP_KANTO                                4343
# San Diego CA                            3484
# Philadelphia PA                         2837
# Roanoke-Lynchburg VA                    2674
# Denver CO                               2572
# Pittsburgh PA                           2131
# Charlotte NC                            1911
# Portland OR                             1805
# Phoenix AZ                              1508
# Orlando-Daytona Beach-Melbourne FL      1425
# San Antonio TX                          1399
# North West                               909
# Miami-Ft. Lauderdale FL                  815
# Columbus OH                              775
# Nashville TN                             774
#                                        ...
# Toledo OH                                 20
# Panama City FL                            20
# East Of England                           20
# HTV Wales                                 20
# Springfield MO                            17
# Colorado Springs-Pueblo CO                16
# Providence-New Bedford,MA                 14
# Wheeling WV-Steubenville OH               14
# Monterey-Salinas CA                       13
# Charlottesville VA                        13
# Anchorage AK                              12
# Erie PA                                   11
# Greenville-New Bern-Washington NC         10
# Abilene-Sweetwater TX                     10
# Wichita-Hutchinson KS                      9
# Flint-Saginaw-Bay City MI                  9
# Mankato MN                                 9
# Ft. Wayne IN                               8
# Tri-Cities TN-VA                           8
# Richmond-Petersburg VA                     7
# Lubbock TX                                 7
# Augusta GA                                 7
# Syracuse NY                                7
# Dayton OH                                  6
# Tallahassee FL-Thomasville GA              6
# Springfield-Holyoke MA                     6
# Des Moines-Ames IA                         6
# Rochester-Mason City-Austin,IA             6
# Champaign & Springfield-Decatur IL         6
# Buffalo NY                                 5
# Name: geoNetwork_metro, Length: 123, dtype: int64
#
#
# geoNetwork_networkDomain
# (not set)                499049
# unknown.unknown          269796
# comcast.net               55486
# rr.com                    28715
# verizon.net               26547
# ttnet.com.tr              17078
# comcastbusiness.net       16826
# hinet.net                 15933
# virginm.net               12594
# cox.net                   10722
# sbcglobal.net             10596
# google.com                 9997
# prod-infinitum.com.mx      9925
# optonline.net              9734
# att.net                    9255
# btcentralplus.com          9152
# rima-tde.net               8078
# 3bb.co.th                  7832
# vnpt.vn                    7662
# asianet.co.th              7067
# qwest.net                  6945
# totbb.net                  6828
# telecomitalia.it           6405
# t-ipconnect.de             6117
# airtelbroadband.in         5991
# bell.ca                    5956
# pldt.net                   5753
# virtua.com.br              5399
# bhn.net                    5363
# amazonaws.com              5039
#                           ...
# gnb.ca                        1
# polinilai.edu.my              1
# zlatograd.net                 1
# marketanalysis.gr             1
# haax.com                      1
# sttspa.it                     1
# mionet.ro                     1
# serverscity.net               1
# westernversatile.com          1
# wlp.is                        1
# only4ultd.co.uk               1
# igua.fi                       1
# sarai.cz                      1
# itgroup.cz                    1
# amcbb.net                     1
# changeofphase.ca              1
# pcwi.net                      1
# sdc.se                        1
# saradarbank.com               1
# aktm.kz                       1
# glencore.cl                   1
# bephenocopy.com               1
# ien.com.pl                    1
# agromey.com.tr                1
# ramcotex.com                  1
# edgemails.com                 1
# cpinvest.cz                   1
# dipro-brno.cz                 1
# toledotel.com                 1
# prospectsifa.com              1
# Name: geoNetwork_networkDomain, Length: 41982, dtype: int64
#
#
# geoNetwork_networkLocation
# not available in demo dataset    1708337
# Name: geoNetwork_networkLocation, dtype: int64
#
#
# geoNetwork_region
# not available in demo dataset    932959
# California                       206669
# (not set)                         49774
# New York                          49733
# England                           25824
# Texas                             20480
# Washington                        15372
# Illinois                          15352
# Maharashtra                       13634
# Bangkok                           12468
# Taipei City                       11901
# Ontario                           11655
# Karnataka                         11447
# Delhi                             11218
# Istanbul                           9827
# Tamil Nadu                         9395
# Ile-de-France                      8962
# New South Wales                    8957
# Telangana                          8374
# County Dublin                      8187
# State of Sao Paulo                 7969
# Ho Chi Minh                        7250
# Hanoi                              7075
# Tokyo                              6968
# Jakarta                            6431
# Massachusetts                      5877
# Tel Aviv District                  5849
# District of Columbia               5700
# Seoul                              5683
# Georgia                            5477
#                                   ...
# Medjimurje County                     6
# Aydin Province                        6
# Abruzzo                               6
# Beni Suef Governorate                 6
# Queretaro                             6
# Nord-Pas-de-Calais                    6
# Lopburi                               6
# Hyogo Prefecture                      6
# Eskisehir Province                    6
# Phu Tho Province                      6
# Maha Sarakham                         6
# Apulia                                6
# Irbid Governorate                     6
# Gharbia Governorate                   6
# Central Java                          6
# Oran Province                         6
# Erzurum                               6
# Split-Dalmatia County                 6
# Sonora                                6
# Hradec Kralove Region                 6
# Rhone-Alpes                           6
# Kyoto Prefecture                      6
# Thuringia                             6
# Jonkoping County                      6
# Gifu Prefecture                       6
# Tyrol                                 6
# Bamako Capital District               6
# State of Rio Grande do Norte          6
# Braga                                 6
# Kumamoto Prefecture                   5
# Name: geoNetwork_region, Length: 483, dtype: int64
#
#
# geoNetwork_subContinent
# Northern America      768345
# Southeast Asia        121634
# Southern Asia         121062
# Western Europe        115153
# Northern Europe       111693
# Eastern Asia           91072
# South America          75112
# Eastern Europe         74007
# Southern Europe        67184
# Western Asia           60966
# Central America        29564
# Australasia            27867
# Northern Africa        17255
# Western Africa          7086
# Southern Africa         6019
# Caribbean               4382
# Eastern Africa          4194
# (not set)               2517
# Central Asia            1985
# Middle Africa            927
# Melanesia                133
# Micronesian Region       128
# Polynesia                 52
# Name: geoNetwork_subContinent, dtype: int64
#
#
# sessionId
# 3369895875786214183_1512028689    2
# 3429979432955165482_1495781717    2
# 7632664392581440337_1524293985    2
# 4853124786988084328_1488527765    2
# 938343955605842538_1514361502     2
# 3668154658566154575_1474872860    2
# 1420483413974308951_1479715163    2
# 0210271036253197119_1515830365    2
# 6976292156999551124_1522911594    2
# 0483440716948649139_1513843127    2
# 0102591489349731382_1507531905    2
# 9781929510750944465_1514793518    2
# 2072942859070557608_1481787032    2
# 5423409296205086026_1524120927    2
# 379810149657100494_1472021940     2
# 2587809593346474510_1474613955    2
# 6226796784105445189_1503470874    2
# 2639757655798808254_1522824978    2
# 8668085394784319119_1480406175    2
# 1530380193041625943_1503556120    2
# 6254741954977355917_1497337196    2
# 4279195933480621280_1490079392    2
# 08738262139931579_1484467175      2
# 8288977169516268127_1482995888    2
# 6257133228617180372_1492498666    2
# 3214835877710485440_1516262074    2
# 3803631788457173476_1518595143    2
# 3405406141103064837_1500533920    2
# 2870781067057815332_1511941827    2
# 4709717629461677286_1511510074    2
#                                  ..
# 3464918413938210065_1493954128    1
# 3670995767270610749_1498031857    1
# 5916371585117057791_1489922824    1
# 3055402265469017652_1498616297    1
# 6159282735809750255_1522755643    1
# 2035812489399754674_1473782748    1
# 6737513341401825736_1505243032    1
# 7148953960785844513_1507285880    1
# 1222771172280403490_1492326835    1
# 3445904603722013334_1521494334    1
# 3667365096455655796_1505635459    1
# 2100594577358291024_1485471747    1
# 568467191389157038_1476304673     1
# 884459688253200639_1492472648     1
# 1755741397435821325_1509162223    1
# 6890503495902509503_1515196447    1
# 9754767779158884291_1502205700    1
# 1699913238647364754_1523154743    1
# 7166503949684701869_1512598925    1
# 645150690471015932_1487699555     1
# 3975311052455875432_1492547348    1
# 8445397108272032087_1477545893    1
# 8306672021080468170_1472752203    1
# 6149958712052593638_1515127411    1
# 6303189321588988219_1485086011    1
# 4660336284439403414_1490911172    1
# 8039746534976266869_1496214412    1
# 0135499118146109299_1475157865    1
# 2600746484292327680_1518612500    1
# 4792822839185962320_1485834622    1
# Name: sessionId, Length: 1706613, dtype: int64
#
#
# socialEngagementType
# Not Socially Engaged    1708337
# Name: socialEngagementType, dtype: int64
#
#
# totals_bounces
# 1.0    871578
# Name: totals_bounces, dtype: int64
#
#
# totals_hits
# 1      864064
# 2      237499
# 3      134435
# 4       80875
# 5       63687
# 6       46598
# 7       38137
# 8       29717
# 9       24999
# 10      20306
# 11      17506
# 12      14877
# 13      13033
# 14      11361
# 15      10017
# 16       8818
# 17       7682
# 18       6924
# 19       6149
# 20       5643
# 21       4938
# 22       4543
# 23       4056
# 24       3746
# 25       3400
# 26       3100
# 27       2698
# 28       2549
# 29       2317
# 30       2257
#         ...
# 233         1
# 228         1
# 183         1
# 217         1
# 216         1
# 186         1
# 212         1
# 210         1
# 204         1
# 202         1
# 241         1
# 244         1
# 291         1
# 245         1
# 283         1
# 282         1
# 281         1
# 280         1
# 278         1
# 276         1
# 273         1
# 265         1
# 260         1
# 259         1
# 252         1
# 251         1
# 250         1
# 249         1
# 246         1
# 221         1
# Name: totals_hits, Length: 297, dtype: int64
#
#
# totals_newVisits
# 1.0    1307430
# Name: totals_newVisits, dtype: int64
#
#
# totals_pageviews
# 1.0      876328
# 2.0      249794
# 3.0      142896
# 4.0       86666
# 5.0       64712
# 6.0       47721
# 7.0       37751
# 8.0       29586
# 9.0       24153
# 10.0      19228
# 11.0      16510
# 12.0      13414
# 13.0      11543
# 14.0       9946
# 15.0       8512
# 16.0       7273
# 17.0       6399
# 18.0       5611
# 19.0       4798
# 20.0       4209
# 21.0       3855
# 22.0       3447
# 23.0       2964
# 24.0       2680
# 25.0       2385
# 26.0       2239
# 27.0       1903
# 28.0       1832
# 29.0       1484
# 30.0       1435
#           ...
# 194.0         1
# 166.0         1
# 159.0         1
# 168.0         1
# 171.0         1
# 173.0         1
# 174.0         1
# 155.0         1
# 154.0         1
# 186.0         1
# 151.0         1
# 189.0         1
# 190.0         1
# 191.0         1
# 195.0         1
# 230.0         1
# 196.0         1
# 197.0         1
# 198.0         1
# 200.0         1
# 201.0         1
# 142.0         1
# 210.0         1
# 213.0         1
# 215.0         1
# 219.0         1
# 220.0         1
# 223.0         1
# 162.0         1
# 500.0         1
# Name: totals_pageviews, Length: 230, dtype: int64
#
#
# totals_transactionRevenue
# 1.699000e+07    256
# 1.899000e+07    189
# 3.359000e+07    187
# 4.479000e+07    170
# 1.359000e+07    135
# 5.599000e+07    122
# 1.999000e+07    116
# 1.599000e+07     98
# 1.519000e+07     93
# 1.919000e+07     92
# 1.099000e+07     84
# 5.999000e+07     81
# 2.499000e+07     77
# 7.999000e+07     65
# 2.719000e+07     64
# 2.718000e+07     62
# 3.398000e+07     54
# 3.999000e+07     51
# 6.718000e+07     46
# 1.990000e+06     44
# 2.878000e+07     40
# 2.199000e+07     40
# 3.598000e+07     39
# 3.039000e+07     39
# 1.759000e+07     38
# 3.038000e+07     37
# 1.299000e+07     37
# 2.798000e+07     37
# 3.199000e+07     37
# 9.999000e+07     35
#                ...
# 1.692700e+08      1
# 1.059000e+07      1
# 1.694500e+08      1
# 1.695700e+08      1
# 1.684900e+08      1
# 1.696000e+08      1
# 1.696100e+08      1
# 1.696800e+08      1
# 1.697000e+08      1
# 1.697500e+08      1
# 1.698000e+08      1
# 1.687300e+08      1
# 1.682500e+08      1
# 1.669500e+08      1
# 1.674800e+08      1
# 1.669700e+08      1
# 1.670900e+08      1
# 1.671500e+08      1
# 1.671700e+08      1
# 1.671800e+08      1
# 1.674000e+08      1
# 1.675500e+08      1
# 2.687400e+09      1
# 1.048000e+07      1
# 1.677500e+08      1
# 1.678700e+08      1
# 1.679300e+08      1
# 1.679400e+08      1
# 1.679600e+08      1
# 1.173700e+08      1
# Name: totals_transactionRevenue, Length: 5332, dtype: int64
#
#
# totals_visits
# 1    1708337
# Name: totals_visits, dtype: int64
#
#
# trafficSource_adContent
# Google Merchandise Store                       39566
# Google Merchandise Collection                   6762
# Placement Accessores 300 x 250                  3040
# Smart display ad - 8/17/2017                    2664
# Display Ad created 3/11/14                      2344
# Google Online Store                             1773
# Official Google Merchandise                      866
# Ad from 12/15/17                                 853
# Full auto ad IMAGE ONLY                          822
# Placement Drinkware 300x250                      653
# Ad from 12/13/16                                 610
# Ad from 11/3/16                                  489
# {KeyWord:Google Brand Items}                     418
# Display Ad created 3/11/15                       392
# Placement Accessories 336 x 280                  308
# BQ                                               287
# Placement Accessories 300 x 250                  280
# {KeyWord:Google Merchandise}                     274
# Placement Accessories 160 x 600                  261
# Placement Elecronics 300 x 250                   190
# Placement 300 x 250                              159
# Swag with Google Logos                           147
# Ad from 11/7/16                                  123
# Drinkware 336x280                                 96
# {KeyWord:Google Branded Gear}                     95
# Bags 300x250                                      90
# {KeyWord:Looking for Google Bags?}                89
# Google Merchandise                                87
# First Full Auto Template Test Ad                  87
# Placement Office 300x250                          80
#                                                ...
# Placement Office 336x280                          15
# Office Placement 160x600                          14
# Accessories Placement 336 x 280                   13
# Bags 160 x 600                                    13
# {KeyWord:Want Google Pet Toys?}                   11
# {KeyWord:Google Branded Apparel}                  10
# Want Google Sunglasses                             9
# Google Paraphernalia                               8
# test_tyler_hr_merchant                             8
# Google Store                                       8
# Full auto ad TEXT/NATIVE                           7
# visit us again                                     7
# Office 2018 - 120 x 600                            7
# Drinkware 120x600                                  6
# {KeyWord:Google Branded Outerwear}                 5
# Official Google Merchandise - Fast Shipping        4
# Full auto ad NATIVE ONLY                           3
# free shipping                                      3
# Ad from 2/17/17                                    3
# url_builder                                        3
# Men's-Outerwear Google Apparel                     3
# Full auto ad with Primary Color                    3
# google store                                       2
# Google store                                       2
# cool                                               2
# Free Shipping!                                     2
# Google Apparel                                     1
# Swag w/ Google Logos                               1
# GA Help Center                                     1
# Men's Apparel from Google                          1
# Name: trafficSource_adContent, Length: 76, dtype: int64
#
#
# trafficSource_adwordsClickInfo.adNetworkType
# Content            42223
# Google Search      33043
# Search partners        8
# Name: trafficSource_adwordsClickInfo.adNetworkType, dtype: int64
#
#
# trafficSource_adwordsClickInfo.criteriaParameters
# not available in demo dataset    1708337
# Name: trafficSource_adwordsClickInfo.criteriaParameters, dtype: int64
#
#
# trafficSource_adwordsClickInfo.gclId
# CN_Whvvc_9UCFd6LswodGTgKCQ                                                                      74
# Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3ZdwYO8GTsjiBFd5MPHStZa9y_9NCrI8X97oaAglc8P8HAQ      70
# COT1-vPT4tYCFZWNswodcwsHxg                                                                      60
# CN3fusbjvtYCFQsmhgodIEQO-g                                                                      51
# Cj0KEQjw1ee_BRD3hK6x993YzeoBEiQA5RH_BEA562M9tvl_mtnAFvtDnDqOQRp1RvxMMgwjcX1LAfwaAj4o8P8HAQ      41
# CI2Ap4L32tYCFY-1wAodeHEHPA                                                                      41
# CPSo2PeD3tYCFYk_GwodJrEEUg                                                                      38
# CKKrvpbe2dYCFdYSaAodSHAOGw                                                                      37
# CP273vOzr9YCFQEHaQoduBgHSA                                                                      35
# CMa4z8jL29YCFdmIswodNRAHRg                                                                      35
# CKvL9K7o-tUCFQ52fgodJ6kAzg                                                                      34
# Cj0KCQjwvabPBRD5ARIsAIwFXBnR4TuWui37oVlyEcaSQzXqoLeI-l6-grsLfOp4-Ng1E8kx-kMu9JcaAlJcEALw_wcB    32
# CIO5_PiPrdYCFVy4wAodz5AMnQ                                                                      32
# CML87ZS65tYCFYUfaAodZrABAQ                                                                      30
# CPmb24WKxtYCFZGNjwod2KYF5A                                                                      29
# CJH1vbf94M8CFUElgQodyakHgQ                                                                      29
# CIDC2quLqdYCFcUYGwodILEENg                                                                      28
# Cj0KEQiAw_DEBRChnYiQ_562gsEBEiQA4LcssmB_RWgvpPnltzlzj5rGwqx5lk87wC5CjfcqzneNZewaAiAp8P8HAQ      27
# CKGykZuz49YCFQaVGwoddowFSw                                                                      25
# CICznoPNs9YCFVhWDQodZuUA1Q                                                                      25
# CjwKEAiAj7TCBRCp2Z22ue-zrj4SJACG7SBEJui6ggr6ocA-eDC2-lX7W1m5IA1c_qNbzwZVTqUanxoCb5rw_wcB        24
# CL76p9jTrdYCFRFXDQod9TgCug                                                                      24
# CNHp7Nf2ytMCFVlWDQod_IoL5A                                                                      24
# CNGEpI-FsdYCFZaFswodY_wAjg                                                                      23
# CjwKCAjwzMbLBRBzEiwAfFz4gYl-AKAIK_80ighQLCXBygB0IWGLYBvX2BOEz89S61dXw8iqDatAohoCigEQAvD_BwE     23
# CN_u9PaVhdACFcNahgodTCQAjw                                                                      22
# CKXg-_2G39YCFUiNjwodpmsM3Q                                                                      22
# CL_V1smS4tUCFQFpfgodyEACiw                                                                      22
# CJTnhpbd4NUCFVeewAod90MJIQ                                                                      21
# CjwKEAiAxKrFBRDm25f60OegtwwSJABgEC-Z0_DLPcXHm1ZTqlR1YWeWXU875yaqwupt7pGMgFEZThoCeEzw_wcB        21
#                                                                                                 ..
# CL3nyb--29YCFdG4wAodP9oHlA                                                                       1
# Cj0KCQjwkN3KBRCuARIsADT_flrvyhOncUtbP-AlgyEAWW5yEuGs3qFKlqcO5y9KRujbA9zxBsvhOqcaAtnCEALw_wcB     1
# CNbh2tS8us4CFYlkhgodyNYDJw                                                                       1
# EAIaIQobChMIlOvlrNGr2AIVx8jjBx3TogT5EAEYASAAEgIj8vD_BwE                                          1
# CJOttf3todACFQ-DaQodODkLzA                                                                       1
# Cj0KEQjw9r7JBRCj37PlltTskaMBEiQAKTzTfCkZiw9_fPbqSaMKu6JQ6HOAGU0h5cA1-bi-As4_inoaAtrn8P8HAQ       1
# CP3B3N3it9YCFYYmhgodv1EFmw                                                                       1
# CJml2PDXyNYCFZaIswodjDgA1w                                                                       1
# CJmR7O2G09YCFUSRfgodoVcBQQ                                                                       1
# CL_JheSGzs4CFZOIaQodBT4F4g                                                                       1
# CLTEpfiy8NACFQWPaQodowAKkA                                                                       1
# CMyFkd3Cw9YCFUiFfgodd-MAZA                                                                       1
# CjwKEAjws5zABRDqkoOniLqfywESJACjdoiGwrunSEk9rv4gzBkhOcXSs7z5OQSsfESmPEbzzc4foBoCfVPw_wcB         1
# EAIaIQobChMI3pSkjpm_2AIVDXQBCh1Zew1gEAEYASAAEgLJIfD_BwE                                          1
# CIbQl4fzvtYCFYQ1aQod-goIzA                                                                       1
# Cj0KCQjwoZTNBRCWARIsAOMZHmGF5LOOozD68LNdVvuFqPSA4LC73XYxCw7dp0bDKn8GQs2Wbjc0SU8aAoywEALw_wcB     1
# CM_RvrX84NYCFVU6gQodKAYDMQ                                                                       1
# EAIaIQobChMI546ozOba2QIVjsDICh0PPgwiEAAYASAAEgLWC_D_BwE                                          1
# Cj0KCQiAyZLSBRDpARIsAH66VQIbHJNdgjZEJ41_mZYONHE7WO2VRRbMGzGIZHSRrKXIUIUPnMfNeSUaAkZvEALw_wcB     1
# CPLVnt_309YCFQkfhgodtj4MnQ                                                                       1
# Cj0KCQiAyszSBRDJARIsAHAqQ4pr4_pWWWFnY-GrSN3TzML9WYdVqkRpUL0IViHWsEaSZtB0-kQ-CHsaAkxBEALw_wcB     1
# CP76jtjPs9YCFZGNswodGFkElg                                                                       1
# CLbh0ajK2M8CFdKGfgodLd4OaQ                                                                       1
# EAIaIQobChMI_ZGN6ODQ2QIVBVt-Ch30pAbTEAAYAiAAEgLhffD_BwE                                          1
# CIyWiLLBvc8CFQ90fgodEaYEVA                                                                       1
# CIXS07_B9NECFQGpaQodmjsELg                                                                       1
# CNCxpdr4gNECFVKewAod8qUNPA                                                                       1
# COzL4JChwdQCFVKCfgodrLQG3Q                                                                       1
# CNqy1PGanNACFZaEaQod4UgEyg                                                                       1
# CMOl_u3ElNACFQ0DaQodhOABcQ                                                                       1
# Name: trafficSource_adwordsClickInfo.gclId, Length: 59008, dtype: int64
#
#
# trafficSource_adwordsClickInfo.isVideoAd
# False    75274
# Name: trafficSource_adwordsClickInfo.isVideoAd, dtype: int64
#
#
# trafficSource_adwordsClickInfo.page
# 1.0     73913
# 2.0      1057
# 3.0       172
# 4.0        80
# 5.0        30
# 6.0        10
# 7.0         6
# 9.0         3
# 14.0        1
# 12.0        1
# 8.0         1
# Name: trafficSource_adwordsClickInfo.page, dtype: int64
#
#
# trafficSource_adwordsClickInfo.slot
# RHS                       42750
# Top                       32447
# Google Display Network       77
# Name: trafficSource_adwordsClickInfo.slot, dtype: int64
#
#
# trafficSource_campaign
# (not set)                                                               1594274
# Data Share Promo                                                          32914
# 1000557 | GA | US | en | Hybrid | GDN Text+Banner | AS                    24410
# AW - Dynamic Search Ads Whole Site                                        23177
# 1000557 | GA | US | en | Hybrid | GDN Remarketing                         15149
# AW - Accessories                                                           9715
# Smart Display Campaign                                                     2664
# "google + redesign/Accessories March 17" All Users Similar Audiences       1179
# Page: contains "/google+redesign/drinkware" Similar Audiences               611
# "google + redesign/Accessories March 17" All Users                          562
# Sports & Fitness/Health & Fitness Buffs                                     463
# Run of Network Line Item                                                    428
# test-liyuhz                                                                 392
# Media & Entertainment/Movie Lovers                                          311
# Technology/Mobile Enthusiasts                                               310
# Technology/Technophiles                                                     290
# Value Shoppers Affinity                                                     208
# Media & Entertainment/Music Lovers                                          195
# Page: contains "/google+redesign/drinkware"                                 192
# Page: contains "/google+redesign/office" Similar Audiences                  182
# Lifestyles & Hobbies/Shutterbugs                                            131
# AW - Electronics                                                             97
# Page: contains "/google+redesign/electronics"                                97
# Page: contains "/google+redesign/office"                                     93
# Page: contains "/google+redesign/bags" All Users                             83
# AW - Apparel                                                                 58
# Retail (DO NOT EDIT owners nophakun and tianyu)                              50
# Page: contains "/google+redesign/bags" All Users Similar Audiences           42
# Page: contains "/google+redesign/bags" 1 Day                                 27
# (direct)                                                                     12
# Page: contains "/google+redesign/electronics" Similar Audiences               9
# "google + redesign/Accessories March 17" 1 Day                                5
# All Products                                                                  4
# Gmail type campaign                                                           2
# Data Share                                                                    1
# Name: trafficSource_campaign, dtype: int64
#
#
# trafficSource_campaignCode
# 11251kjhkvahf    1
# Name: trafficSource_campaignCode, dtype: int64
#
#
# trafficSource_isTrueDirect
# True    534518
# Name: trafficSource_isTrueDirect, dtype: int64
#
#
# trafficSource_keyword
# (not provided)                                                                         712754
# (User vertical targeting)                                                               26250
# (automatic matching)                                                                    18781
# 6qEhsCssdK0z36ri                                                                        17724
# (Remarketing/Content targeting)                                                          7238
# 1hZbAqLCbjwfgOH7                                                                         3996
# google merchandise store                                                                 2987
# Google Merchandise                                                                       2128
# google store                                                                             1580
# 1X4Me6ZKNV0zg-jV                                                                         1447
# DoubleClick Ad Exchange                                                                   778
# youtube                                                                                   770
# +Google +Merchandise                                                                      548
# +google +store                                                                            547
# +google +merchandise +store                                                               383
# google merchandise                                                                        324
# +google +stores                                                                           323
# google merch                                                                              313
# https://www.googlemerchandisestore.com/                                                   302
# (content targeting)                                                                       301
# youtube merch                                                                             277
# https://goto.google.com/a/google.com?continue=https://goto.google.com/tyctwd-shirts       264
# YouTube Merchandise                                                                       263
# +Google +Products                                                                         254
# Youtube                                                                                   216
# merchandise store                                                                         188
# google shop                                                                               174
# youtube t shirt                                                                           171
# google t shirt                                                                            150
# +Google +Swag                                                                             148
#                                                                                         ...
# gogle and mooch wali girl t shirt                                                           1
# googal mick power bank                                                                      1
# YouTube home                                                                                1
# google mercendise store india                                                               1
# red google mug                                                                              1
# hat google buy                                                                              1
# argos lava lamp                                                                             1
# google, belfry t shirts                                                                     1
# Google Developer t shirt                                                                    1
# These mateial are not available in store please provide us                                  1
# Google!                                                                                     1
# 96547565 tracking number pls search where is it                                             1
# google atore canada                                                                         1
# Google printed t shirts                                                                     1
# google online shops                                                                         1
# white google tshirt                                                                         1
# lava lights                                                                                 1
# back pack                                                                                   1
# google astore                                                                               1
# γοογλε                                                                                      1
# 14 oz                                                                                       1
# WWW GOOGGOL                                                                                 1
# google storre                                                                               1
# Youtube merch for sale                                                                      1
# google clothing site                                                                        1
# google company in usa                                                                       1
# google sotre                                                                                1
# गूगल स्टोर                                                                                  1
# googal compny ragstior obline                                                               1
# Mickey Clothing you tubes                                                                   1
# Name: trafficSource_keyword, Length: 5392, dtype: int64
#
#
# trafficSource_medium
# organic      738963
# referral     566278
# (none)       273134
# cpc           87850
# affiliate     32915
# cpm            9060
# (not set)       137
# ...
# /yt/advertise/                                                                                                                                                                7511
# /yt/about/es/                                                                                                                                                                 7095
# /yt/about/en-GB/                                                                                                                                                              6582
# /yt/creators/                                                                                                                                                                 6138
# /a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts                                                                                            6016
# /yt/about/copyright/                                                                                                                                                          5894
# /yt/about/fr/                                                                                                                                                                 5705
# /yt/about/ja/                                                                                                                                                                 4680
# /yt/about/press/                                                                                                                                                              4309
# /yt/about/ar/                                                                                                                                                                 4295
# /yt/about/policies/                                                                                                                                                           4176
# /yt/about/pl/                                                                                                                                                                 3617
# /pagead/ads                                                                                                                                                                   3608
# /YKEI_mrn/items/c10b14f9a69ff71b1b7a                                                                                                                                          3358
# /yt/dev/                                                                                                                                                                      3347
# /yt/about/de/                                                                                                                                                                 2863
# /analytics/app/                                                                                                                                                               2859
# /intl/en/yt/advertise/                                                                                                                                                        2843
# /yt/about/zh-TW/                                                                                                                                                              2800
#                                                                                                                                                                              ...
# /How-hard-is-it-to-get-a-Google-Code-Jam-T-shirt                                                                                                                                 1
# /a/google.com/nestlabs/-nestlife/wellness-week                                                                                                                                   1
# /from=1269a/bd_page_type=1/ssid=0/uid=0/pu=usm%400%2Csz%401321_1004%2Cta%40utouch_2_4.1_11_2.1/baiduid=9341382C2E97BEC7B16C325EC68C0932/w=0_10_store+google/t=wap/l=3/tc         1
# /intl/id/yt/creators/learn-and-connect/                                                                                                                                          1
# /intl/th/yt/space/tokyo/                                                                                                                                                         1
# /intl/fr/yt/about/copyright/fair-use/                                                                                                                                            1
# /document/d/1X1A4sKXMZSKLr3OByBqtewvc6Y3lIEqPfWtBXv3u5Wo/edit                                                                                                                    1
# /intl/id/yt/nextup/                                                                                                                                                              1
# /youtube/forum/AAAAtMBnpzw3xfCBccRfq4                                                                                                                                            1
# /i/subscription/feed/http://feeds.feedburner.com/stadt-bremerhaven/dqXM                                                                                                          1
# /d2l/common/assets/pdfjs/web/viewer.html                                                                                                                                         1
# /gp/registry/wishlist/2U81BY9YC5TG8/ref=nav_wishlist_lists_1                                                                                                                     1
# /yt/dev/ru/api-resources.html                                                                                                                                                    1
# /from=844b/bd_page_type=1/ssid=0/uid=0/pu=usm%401%2Csz%40320_1002%2Cta%40iphone_2_6.0_2_6.0/baiduid=8B5CED302755A8A3BADD554D1E7DC07E/w=0_10_/t=iphone/l=3/tc                     1
# /from=1012852y/bd_page_type=1/ssid=0/uid=0/pu=usm%404%2Csz%40320_1004%2Cta%40iphone_2_5.0_11_9.1/baiduid=2E9404E7C4F0D06A76A677668AA2A0B9/w=0_10_/t=iphone/l=3/tc                1
# /from=1000953c/bd_page_type=1/ssid=0/uid=0/pu=usm%402%2Csz%40320_1002%2Cta%40iphone_2_6.0_2_6.0/baiduid=C8BA95E58082F18B9B964991BCA142EF/w=0_10_/t=iphone/l=3/tc                 1
# /intl/de/yt/advertise/running-a-video-ad/                                                                                                                                        1
# /intl/sv_ALL/yt/advertise/success-stories/                                                                                                                                       1
# /intl/ja_ALL/yt/advertise/resources/beginners-guide-to-video-insights-metrics/                                                                                                   1
# /from=2001a/bd_page_type=1/ssid=0/uid=0/pu=usm%402%2Csz%40320_1003%2Cta%40iphone_2_6.0_1_11.4/baiduid=977641FDA9C60E0C7E415EB039387FA6/w=0_10_/t=iphone/l=3/tc                   1
# /intl/zh-CN/yt/creators-for-change/ambassadors-and-fellows.html                                                                                                                  1
# /intl/kn/yt/about/policies/                                                                                                                                                      1
# /mail/mu/mp/975/                                                                                                                                                                 1
# /i/entry/J8RgRC2V32tUb0LLykaIdq+bSFhis8T3xqVO9X3fAr0=_156519871fb:a3bad7:944ed58e                                                                                                1
# /pagead/gadgets/dynamic_in_page_V1/Responsive_arcadian_able.html                                                                                                                 1
# /from=844b/bd_page_type=1/ssid=0/uid=0/pu=usm%404%2Csz%401320_2001%2Cta%40iphone_1_10.3_3_603/baiduid=9A7CD6B574919C6EAA13ED398C39A7C2/w=0_10_/t=iphone/l=3/tc                   1
# /mail/mu/mp/673/                                                                                                                                                                 1
# /yt/lineups/fr/france.html                                                                                                                                                       1
# /intl/da_ALL/yt/advertise/success-stories/                                                                                                                                       1
# /mail/mu/mp/298/                                                                                                                                                                 1
# Name: trafficSource_referralPath, Length: 3196, dtype: int64
#
#
# trafficSource_source
# google                                               817892
# youtube.com                                          329450
# (direct)                                             273152
# mall.googleplex.com                                  120541
# analytics.google.com                                  37436
# Partners                                              32931
# sites.google.com                                       9072
# google.com                                             8341
# gdeals.googleplex.com                                  8298
# m.facebook.com                                         6737
# dfa                                                    6704
# baidu                                                  4971
# reddit.com                                             4092
# facebook.com                                           3584
# googleads.g.doubleclick.net                            3539
# qiita.com                                              3394
# bing                                                   3368
# quora.com                                              3032
# mail.google.com                                        2558
# yahoo                                                  2436
# siliconvalley.about.com                                2097
# groups.google.com                                      2009
# t.co                                                   2005
# l.facebook.com                                         1529
# moma.corp.google.com                                   1507
# blog.golang.org                                        1382
# tpc.googlesyndication.com                              1277
# dealspotr.com                                           750
# support.google.com                                      676
# productforums.google.com                                672
#                                                       ...
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9828         1
# thompj.mtv.corp.google.com:7000                           1
# google.ee                                                 1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9881         1
# ipv6.google.com                                           1
# adwords-prod-west.qa.adz.google.com                       1
# adwords-next-nightly.qa.adz.google.com                    1
# ipv4.google.com                                           1
# m.wikihow.com                                             1
# images.google.co.in                                       1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9884         1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9850         1
# yt-go-12345.googleplex.com                                1
# 0.shared.bow.cat2.ads-bow.lf.borg.google.com:9817         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9831         1
# 0.shared.bow.cat2.ads-bow.vu.borg.google.com:9883         1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9807         1
# mycrabnet.googleplex.com                                  1
# redwood.corp.google.com                                   1
# tumblr.com                                                1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9885         1
# fr.yhs4.search.yahoo.com                                  1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9861         1
# wanelo.com                                                1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9851         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9846         1
# meetup.com                                                1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9858         1
# confidential-mail.google.com                              1
# invincible.mtv.corp.google.com:8080                       1
# Name: trafficSource_source, Length: 500, dtype: int64
#
#
# visitId
# 1513124981    28
# 1513125098    28
# 1513124949    26
# 1513125008    24
# 1513124997    24
# 1513125049    23
# 1513125079    23
# 1513125073    22
# 1513125026    22
# 1513125004    22
# 1513125074    22
# 1513125057    22
# 1513124958    21
# 1513124969    21
# 1513125064    21
# 1513125020    21
# 1513125066    21
# 1513124983    21
# 1513125053    21
# 1513125104    21
# 1513124957    20
# 1513125016    20
# 1513125095    20
# 1513125078    20
# 1513125002    20
# 1513124942    20
# 1513125068    20
# 1513125038    20
# 1513125045    20
# 1513125090    19
#               ..
# 1474671073     1
# 1478336479     1
# 1470470628     1
# 1474662885     1
# 1505998506     1
# 1479014824     1
# 1474390394     1
# 1525121447     1
# 1486971259     1
# 1507940732     1
# 1470185855     1
# 1491509635     1
# 1474730372     1
# 1516697992     1
# 1499914635     1
# 1504104845     1
# 1514654981     1
# 1495712143     1
# 1504065936     1
# 1520841105     1
# 1490749456     1
# 1487274391     1
# 1495693720     1
# 1470523802     1
# 1502445815     1
# 1510173007     1
# 1478994338     1
# 1525129635     1
# 1514287871     1
# 1505759234     1
# Name: visitId, Length: 1665802, dtype: int64
#
#
# visitNumber
# 1      1307430
# 2       182542
# 3        70962
# 4        37886
# 5        23314
# 6        15702
# 7        11194
# 8         8338
# 9         6350
# 10        5018
# 11        4007
# 12        3283
# 13        2729
# 14        2311
# 15        1981
# 16        1737
# 17        1512
# 18        1346
# 19        1195
# 20        1073
# 21         955
# 22         866
# 23         766
# 24         716
# 25         661
# 26         603
# 27         549
# 28         506
# 29         466
# 30         436
#         ...
# 332          1
# 394          1
# 368          1
# 367          1
# 366          1
# 365          1
# 347          1
# 348          1
# 352          1
# 393          1
# 395          1
# 415          1
# 407          1
# 414          1
# 413          1
# 412          1
# 411          1
# 410          1
# 409          1
# 408          1
# 406          1
# 398          1
# 405          1
# 404          1
# 351          1
# 402          1
# 401          1
# 456          1
# 399          1
# 457          1
# Name: visitNumber, Length: 457, dtype: int64
#
#
# visitStartTime
# 1513124981    28
# 1513125098    28
# 1513124949    26
# 1513124997    24
# 1513125008    24
# 1513125049    23
# 1513125079    23
# 1513125074    22
# 1513125004    22
# 1513125073    22
# 1513125026    22
# 1513125057    22
# 1513124969    21
# 1513124958    21
# 1513125053    21
# 1513125020    21
# 1513125064    21
# 1513125104    21
# 1513124983    21
# 1513125066    21
# 1513125068    20
# 1513125045    20
# 1513125095    20
# 1513125078    20
# 1513125038    20
# 1513125002    20
# 1513125016    20
# 1513124957    20
# 1513124942    20
# 1513124971    19
#               ..
# 1514378533     1
# 1476311057     1
# 1489229101     1
# 1514390831     1
# 1481497836     1
# 1523418343     1
# 1498293395     1
# 1516369021     1
# 1523479705     1
# 1523471517     1
# 1502588066     1
# 1506049395     1
# 1524108053     1
# 1481194224     1
# 1481585841     1
# 1481579700     1
# 1473186998     1
# 1485767863     1
# 1498377402     1
# 1519342781     1
# 1477225666     1
# 1506596045     1
# 1473039566     1
# 1510786255     1
# 1519140048     1
# 1477967087     1
# 1523324117     1
# 1510767832     1
# 1514960089     1
# 1505759234     1
# Name: visitStartTime, Length: 1667423, dtype: int64

# %% [markdown]
# ## 3. Data Pre-processing

# %% [markdown]
# #### Finding columns with just one value in it
#
# Finding the columns with  <br>
# i) If the number of unique values is just one <br>
# ii) More than 50% of NA values <br><br>
#
# Dropping such columns

# %%
### Selecting columns with just one unique value and those with NULL values greater than 50% of the dataset
drop_columns = [each for each in all_data.columns if len(train[each].unique()) <= 2 or all_data[each].isnull().sum() > 0.5 * all_data.shape[0]]
drop_columns = [each for each in drop_columns if each not in ['totals_transactionRevenue','data_source']]

# %%
all_data_upd = all_data.drop(drop_columns, axis = 1)

# %% [markdown]
# #### Feature Engineering: Creating date variables

# %%
all_data_upd['year'] = all_data_upd.date.apply(lambda x: int(str(x)[0:4]))
all_data_upd['month'] = all_data_upd.date.apply(lambda x: int(str(x)[4:6]))
all_data_upd['day'] = all_data_upd.date.apply(lambda x: int(str(x)[6:8]))

# %% [markdown]
# #### Cleaning and imputing train and test separately - since we do not want to use the test data to impute the training data

# %%
train_upd = all_data_upd[all_data_upd.data_source == 'train']
test_upd = all_data_upd[all_data_upd.data_source == 'test']

print(train_upd.shape)
print(test_upd.shape)
# Out:
# (903653, 27)
# (804684, 27)

# %% [markdown]
# Viewing Training dataset

# %%
train_upd.head()
# Out:
#   channelGrouping data_source      date device_browser device_deviceCategory  \
# 0  Organic Search       train  20160902         Chrome               desktop
# 1  Organic Search       train  20160902        Firefox               desktop
# 2  Organic Search       train  20160902         Chrome               desktop
# 3  Organic Search       train  20160902     UC Browser               desktop
# 4  Organic Search       train  20160902         Chrome                mobile
#
#   device_operatingSystem        fullVisitorId                geoNetwork_city  \
# 0                Windows  1131660440785968503                          Izmir
# 1              Macintosh   377306020877927890  not available in demo dataset
# 2                Windows  3895546263509774583                         Madrid
# 3                  Linux  4763447161404445595  not available in demo dataset
# 4                Android    27294437909732085  not available in demo dataset
#
#   geoNetwork_continent geoNetwork_country ... totals_transactionRevenue  \
# 0                 Asia             Turkey ...                       NaN
# 1              Oceania          Australia ...                       NaN
# 2               Europe              Spain ...                       NaN
# 3                 Asia          Indonesia ...                       NaN
# 4               Europe     United Kingdom ...                       NaN
#
#   trafficSource_campaign trafficSource_medium trafficSource_source  \
# 0              (not set)              organic               google
# 1              (not set)              organic               google
# 2              (not set)              organic               google
# 3              (not set)              organic               google
# 4              (not set)              organic               google
#
#       visitId  visitNumber  visitStartTime  year month day
# 0  1472830385            1      1472830385  2016     9   2
# 1  1472880147            1      1472880147  2016     9   2
# 2  1472865386            1      1472865386  2016     9   2
# 3  1472881213            1      1472881213  2016     9   2
# 4  1472822600            2      1472822600  2016     9   2
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Imputation for Trainining dataset

# %%
## Cleaning the character columns in the data

#Float columns
float_cols = []


for each in train_upd.columns:
    
    if(each == 'data_source'):
        continue
        
    if(train_upd[each].dtype == 'O' and len(train_upd[each].unique()) < 500000):
        print(each)
        ### Skipping the values are actually numeric or float
        
        if( not (len(pd.to_numeric(train_upd[each],errors = 'coerce').unique()) < 0.5 * len(train_upd[each].unique())) ):
            
            train_upd.loc[:,each] = train_upd[each].fillna(train_upd[each].mean())
            float_cols.append(each)
            
        else:


            print(len(train_upd[each].unique()))
            train_upd.loc[:,each] = train_upd[each].apply(lambda x: x.lower().strip())
            extreme_values = train_upd[each].value_counts()[train_upd[each].value_counts() < 10].index

            ## Replacing the outliers (extreme) values with 'Others'

            train_upd.loc[:,each] = train_upd[each].apply(lambda x: np.where(x in extreme_values, 'Others',x))
# Out:
# channelGrouping
# 8
# C:\Users\arvra\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# device_browser
# 54
# device_deviceCategory
# 3
# device_operatingSystem
# 20
# geoNetwork_city
# 649
# geoNetwork_continent
# 6
# geoNetwork_country
# 222
# geoNetwork_metro
# 94
# geoNetwork_networkDomain
# 28064
# geoNetwork_region
# 376
# geoNetwork_subContinent
# 23
# trafficSource_campaign
# 10
# trafficSource_medium
# 7
# trafficSource_source
# 380

# %% [markdown]
# #### Imputation for Test dataset

# %%
## Cleaning the character columns in the data

for each in test_upd.columns:
    
    
    if(each == 'data_source'):
        continue
    
    print(each)
    if(test_upd[each].dtype == 'O' and len(test_upd[each].unique()) < 500000):
            
        ### Skipping the values are actually numeric or float
        
        ### Identifying the columns as numeric/float as per the training data
        if(each in float_cols):
            
            train_upd[each] = train_upd[each].fillna(train_upd[each].mean())
        else:


            print(len(train_upd[each].unique()))
            train_upd[each] = train_upd[each].apply(lambda x: x.lower().strip())
            extreme_values = train_upd[each].value_counts()[train_upd[each].value_counts() < 10].index

            ## Replacing the outliers (extreme) values with 'Others'

            train_upd[each] = train_upd[each].apply(lambda x: np.where(x in extreme_values, 'Others',x))
# Out:
# channelGrouping
# 8
# C:\Users\arvra\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\arvra\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# date
# device_browser
# 27
# device_deviceCategory
# 3
# device_operatingSystem
# 15
# fullVisitorId
# geoNetwork_city
# 482
# geoNetwork_continent
# 6
# geoNetwork_country
# 188
# geoNetwork_metro
# 79
# geoNetwork_networkDomain
# 3017
# geoNetwork_region
# 318
# geoNetwork_subContinent
# 23
# sessionId
# totals_hits
# totals_pageviews
# totals_transactionRevenue
# trafficSource_campaign
# 9
# trafficSource_medium
# 7
# trafficSource_source
# 124
# visitId
# visitNumber
# visitStartTime
# year
# month
# day

# %% [markdown]
# #### Combining the data again

# %%
all_data_upd = pd.concat([train_upd,test_upd], axis = 0)

# %% [markdown]
# #### Creating Label Encodings for certain columns

# %%
### Getting encoder function for python
### Columns for transforming
## device_browser','geoNetwork_metro','geoNetwork_networkDomain','geoNetwork_region',
## 'trafficSource_source','geoNetwork_city','geoNetwork_country'


from sklearn.preprocessing import LabelEncoder
###################################################
device_browser = LabelEncoder()
device_browser.fit(all_data_upd.device_browser)

all_data_upd['device_browser_enc'] = device_browser.transform(all_data_upd.device_browser)
###############################################
geoNetwork_metro = LabelEncoder()
geoNetwork_metro.fit(all_data_upd.geoNetwork_metro)

all_data_upd['geoNetwork_metro_enc'] = geoNetwork_metro.transform(all_data_upd.geoNetwork_metro)
###############################################
geoNetwork_networkDomain = LabelEncoder()
geoNetwork_networkDomain.fit(all_data_upd.geoNetwork_networkDomain)

all_data_upd['geoNetwork_networkDomain_enc'] = geoNetwork_networkDomain.transform(all_data_upd.geoNetwork_networkDomain)
###############################################
geoNetwork_region = LabelEncoder()
geoNetwork_region.fit(all_data_upd.geoNetwork_region)

all_data_upd['geoNetwork_region_enc'] = geoNetwork_region.transform(all_data_upd.geoNetwork_region)
###############################################
trafficSource_source = LabelEncoder()
trafficSource_source.fit(all_data_upd.trafficSource_source)

all_data_upd['trafficSource_source_enc'] = trafficSource_source.transform(all_data_upd.trafficSource_source)
###############################################
geoNetwork_city = LabelEncoder()
geoNetwork_city.fit(all_data_upd.geoNetwork_city)

all_data_upd['geoNetwork_city_enc'] = geoNetwork_city.transform(all_data_upd.geoNetwork_city)
###############################################
geoNetwork_country = LabelEncoder()
geoNetwork_country.fit(all_data_upd.geoNetwork_country)

all_data_upd['geoNetwork_country_enc'] = geoNetwork_country.transform(all_data_upd.geoNetwork_country)
##############################################

# %%
## Columns that has more than ~200 distinct objects will create multiple columns while creating one hot vectors
### So, instead of dropping them, we encode those variables into numerical values

## Dropping such columns
all_data_upd = all_data_upd.drop(['device_browser','geoNetwork_metro','geoNetwork_networkDomain','geoNetwork_region',
                                  'trafficSource_source','geoNetwork_city','geoNetwork_country'], axis = 1)

## Getting the datashape
all_data_upd.shape
# Out:
# (1708337, 27)

# %%
all_data_upd['totals_transactionRevenue'] = all_data_upd['totals_transactionRevenue'].fillna(0)
all_data_upd = all_data_upd.fillna(0)

# %%
### Removing id columns
id_cols = ['sessionId','fullVisitorId','visitId','date']
all_data_dummies = pd.get_dummies(all_data_upd.drop(id_cols, axis = 1), dummy_na = True)

# %%
all_data_dummies.shape
# Out:
# (1708337, 182)

# %% [markdown]
# #### Saving the transformed train data

# %%
#all_data_dummies.to_csv('all_data_dummies.csv', index = False, encoding = 'utf8')
all_data_dummies = pd.read_csv("all_data_dummies.csv", encoding = 'utf8')

# %%
all_data_dummies.shape
# Out:
# (1708337, 182)

# %% [markdown]
# #### Dividing the data into train and test

# %%
train_dummies = all_data_dummies[all_data_dummies.data_source_train == 1]
test_dummies = all_data_dummies[all_data_dummies.data_source_test == 1]

# train_dummies = all_data_upd[all_data_upd.data_source == 'train']
# test_dummies = all_data_upd[all_data_upd.data_source == 'test']

# %% [markdown]
# ### Creating the dataset that is model-ready

# %%
train_dummies = train_dummies.drop(['data_source_train','data_source_test','data_source_nan'], axis = 1)
test_dummies = test_dummies.drop(['data_source_train','data_source_test','data_source_nan','totals_transactionRevenue'], axis = 1)

#train_dummies = train_dummies.drop(['data_source'], axis = 1)
#test_dummies = test_dummies.drop(['data_source','totals.transactionRevenue'], axis = 1)

# %% [markdown]
# #### Creating Validation Dataset (Holdout data)
#
# Note: The response variable is changed to log values of the totals_transactionRevenue for better accuracy. Normal transaction was compared agains log values and log values resulted in better scores

# %%
X_train, X_test, y_train, y_test = train_test_split(train_dummies.drop(['totals_transactionRevenue'], axis = 1), \
                  np.log(train_dummies['totals_transactionRevenue']+1),test_size = 0.2, random_state = 9)

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-73020798007e> in <module>()
# ----> 1 X_train.head()
#
# NameError: name 'X_train' is not defined

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (722922, 178)
# (722922,)

# %%
#### Response variable for logistic regression
y_train_logistic = np.where(y_train != 0,1,0)

# %% [markdown]
# ## 4. Model Building
#
# There will be two types of models<br><br>
# 1) Logistic Regression to predict where we have to predict if the value is zero or non-zero <br>
# 2) Linear Regression to predict the actual Revenue <br>
#     &emsp; 2.1) OLS <br>
#     &emsp; 2.2) Random forest <br>
#     &emsp; 2.3) Splines <br>

# %% [markdown]
# ### 4.1 Logistic Regression

# %% [markdown]
#  Model to find where we have 0 revenue and 1 (non-zero) revenue

# %%
### Model building - logistic regression
log_model = LogisticRegression(C = 0.1,solver = 'newton-cg')
log_model.fit(X_train,y_train_logistic)
# Out:
# C:\Users\arvra\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:461: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\arvra\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\arvra\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:421: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# C:\Users\arvra\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# 722921.9999999999

# %% [markdown]
# ##### Model Prediction - train and test

# %%
#### Predicting the values - Obtaining prediction probability to manually specify a threshold value

threshold = 0.02
pred_vals = log_model.predict_proba(X_train)
pred_vals_test = log_model.predict_proba(X_test)

##Getting prediction 
pred_outs_train = np.array(list(map(lambda x: np.where(x[1]>threshold,1,0).sum(),pred_vals)))
pred_outs_test = np.array(list(map(lambda x: np.where(x[1]>threshold,1,0).sum(),pred_vals_test)))

# %% [markdown]
# ### 4.2 Regression Models
# #### 4.2.1 OLS Models

# %%
lr_model = LinearRegression(n_jobs = -1)

# %%
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
predict = np.exp(lr_model.predict(X_train))
predict_test = np.exp(lr_model.predict(X_test))


##### Making the predictions zeros where-ever logistic regression predicted zero

predict[pred_outs_train == 0] = 0
predict_test[pred_outs_test == 0] = 0

# %% [markdown]
# #### Calculating prediction Error

# %% [markdown]
# #### Training data - LMSE

# %%
lmse = np.sum(np.log((np.exp(y_train.values) -  pred_outs) ** 2 + 1))/len(y_train.values)
lmse
# Out:
# 1.107022330147064

# %% [markdown]
# #### Validation data - LMSE

# %%
lmse = np.sum(np.log((np.exp(y_test.values) - predict_test)**2 + 1))/len(y_test.values)
lmse
# Out:
# 1.3141603875638257

# %% [markdown]
# ### Predicting the actual test class<br>
#
# Step 1: Run the logistic Regression Model <br>
# Step 2: Run the linear Regression Model and make non-zero predictions only for those which had non-zero prediction o/p from logistic regression

# %% [markdown]
# #### Step1. Logistic Prediction

# %%
pred_vals_actual_test = log_model.predict_proba(test_dummies)

##Getting prediction 
pred_outs_actual_test = np.array(list(map(lambda x: np.where(x[1]>threshold,1,0).sum(),pred_vals_actual_test)))

# %% [markdown]
# #### Step2. Linear Regression Prediction

# %%
predict_actual_test = lr_model.predict(test_dummies)

predict_actual_test[pred_outs_actual_test == 0] = 0

# %%
submission = pd.concat([test.fullVisitorId,pd.DataFrame(pred_outs_actual_test)], axis = 1)
submission.columns.values[1]= 'PredictedLogRevenue'

# %%
submission_out = submission.groupby('fullVisitorId',as_index = False).sum()

# %%
submission_out.to_csv("kaggle_submission.csv", index = False)

# %% [markdown]
# #### 4.2.2 Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#### The arguments of Random Forest were changed constantly based on the error on validation dataset
rf_regression = RandomForestRegressor(n_estimators= 15)

### Fitting the random forest model
rf_regression.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
#### Predictions for the train and validation dataste

#Prediction for training data
rf_predictions = np.exp(rf_regression.predict(X_train))

#Prediction for validation data
rf_predictions_test = np.exp(rf_regression.predict(X_test))

# %%
### Using the predictions from logistic regression - to make the values zeros of those predicted as zeros from logistic regression
rf_predictions[pred_outs_train == 0] = 0
rf_predictions_test[pred_outs_test == 0] = 0


lmse = np.sum(np.log((np.exp(y_train.values) -  rf_predictions) ** 2 + 1))/len(y_train.values)
print("Train Error: ",lmse)

lmse = np.sum(np.log((np.exp(y_test.values) -  rf_predictions_test) ** 2 + 1))/len(y_train.values)
print("Validation Error: ",lmse)

#### The validation error dropped sig
# Out:
# Train Error:  1.1861137129396992
# Validation Error:  0.33729268912108146

# %%
#### To do:

## For visualiation: https://www.kaggle.com/pavansanagapati/simple-exploration-lgbm-model-lb-1-4187 
## Implement the globe

## For categorical features - implement the Encoders and proper imputation
## For columns with webties - extract the major website name (google.com/google.in have the same major content google)
## Numerical features - better imputation and try to create more variables


## Futher, implement a logistic regression and then perfrom a non-linear model on top
